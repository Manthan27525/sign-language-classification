# %%
import os
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, optimizers
import numpy as np
import pathlib
import cv2
import json

# %%
DATA_DIR = "../data/raw/ASL_Dataset/"   # <<-- change this to your dataset path
IMG_SIZE = 64
BATCH_SIZE = 32
AUTOTUNE = tf.data.AUTOTUNE
EPOCHS = 40
PATIENCE = 6
MODEL_SAVE_PATH = "gesture_model.h5"
SEED = 123


train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    DATA_DIR,
    labels="inferred",
    label_mode="categorical",   # one-hot labels
    batch_size=BATCH_SIZE,
    image_size=(IMG_SIZE, IMG_SIZE),
    shuffle=True,
    seed=SEED,
    validation_split=0.2,
    subset="training",
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    DATA_DIR,
    labels="inferred",
    label_mode="categorical",
    batch_size=BATCH_SIZE,
    image_size=(IMG_SIZE, IMG_SIZE),
    shuffle=True,
    seed=SEED,
    validation_split=0.2,
    subset="validation",
)

class_names = train_ds.class_names
NUM_CLASSES = len(class_names)
print("Classes:", class_names, "NUM_CLASSES=", NUM_CLASSES)


def rgb_to_gray_and_scale(images, labels):
    # images: float32 in [0,255]
    images = tf.image.rgb_to_grayscale(images)                      # -> (B, H, W, 1)
    images = tf.cast(images, tf.float32) / 255.0                    # -> [0,1]
    return images, labels


data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.08),         # +- ~15 degrees
    layers.RandomZoom(0.08),
    layers.RandomTranslation(0.05, 0.05),
    layers.RandomContrast(0.1),
], name="data_augmentation")

def augment(images, labels):

    return data_augmentation(images), labels


train_ds = train_ds.map(lambda x, y: (tf.image.rgb_to_grayscale(x), y), num_parallel_calls=AUTOTUNE)
train_ds = train_ds.map(lambda x, y: (tf.cast(x, tf.float32) / 255.0, y), num_parallel_calls=AUTOTUNE)
train_ds = train_ds.map(lambda x, y: (data_augmentation(x), y), num_parallel_calls=AUTOTUNE)
train_ds = train_ds.prefetch(AUTOTUNE)

val_ds = val_ds.map(lambda x, y: (tf.image.rgb_to_grayscale(x), y), num_parallel_calls=AUTOTUNE)
val_ds = val_ds.map(lambda x, y: (tf.cast(x, tf.float32) / 255.0, y), num_parallel_calls=AUTOTUNE)
val_ds = val_ds.prefetch(AUTOTUNE)
# Out:
# Found 165782 files belonging to 28 classes.
# Using 132626 files for training.
# Found 165782 files belonging to 28 classes.
# Using 33156 files for validation.
# Classes: ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L', 'M', 'N', 'Nothing', 'O', 'P', 'Q', 'R', 'S', 'Space', 'T', 'U', 'V', 'W', 'X', 'Y', 'Z'] NUM_CLASSES= 28

# %%
def build_light_cnn(input_shape=(IMG_SIZE, IMG_SIZE, 1), num_classes=NUM_CLASSES):
    inputs = layers.Input(shape=input_shape)

    # Conv Block 1
    x = layers.Conv2D(16, (3,3), padding="same", activation=None)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.MaxPooling2D((2,2))(x)

    # Conv Block 2
    x = layers.Conv2D(32, (3,3), padding="same", activation=None)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.MaxPooling2D((2,2))(x)

    # Conv Block 3
    x = layers.Conv2D(64, (3,3), padding="same", activation=None)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.MaxPooling2D((2,2))(x)

    # Flatten and Dense
    x = layers.Flatten()(x)
    x = layers.Dense(128, activation="relu")(x)
    x = layers.Dropout(0.4)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = models.Model(inputs, outputs, name="LightweightGestureCNN")
    return model

model = build_light_cnn()
model.compile(optimizer=optimizers.Adam(learning_rate=1e-3),
              loss="categorical_crossentropy",
              metrics=["accuracy"])

model.summary()

# ---------------------------
# Callbacks
# ---------------------------
checkpoint_cb = callbacks.ModelCheckpoint("../model/best_gesture_model.h5", save_best_only=True, monitor="val_accuracy", mode="max")
earlystop_cb = callbacks.EarlyStopping(monitor="val_loss", patience=PATIENCE, restore_best_weights=True)
reduce_lr_cb = callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6)

# ---------------------------
# Train
# ---------------------------
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[checkpoint_cb, earlystop_cb, reduce_lr_cb]
)



MODEL_SAVE_PATH="../model/gesture_model.h5"

model.save(MODEL_SAVE_PATH)
print(f"Saved model to {MODEL_SAVE_PATH}")

# Optionally, save the class names mapping
with open("class_names.json", "w") as f:
    json.dump(class_names, f)
# Out:
# Model: "LightweightGestureCNN"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 64, 64, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 64, 64, 16)     │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 64, 64, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 64, 64, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 32, 32, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 4096)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       524,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 28)             │         3,612 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 551,772 (2.10 MB)
#  Trainable params: 551,548 (2.10 MB)
#  Non-trainable params: 224 (896.00 B)
# Epoch 1/40
# 4144/4145 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.2667 - loss: 2.2538
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 4145/4145 ━━━━━━━━━━━━━━━━━━━━ 411s 98ms/step - accuracy: 0.3697 - loss: 1.8345 - val_accuracy: 0.4790 - val_loss: 1.6415 - learning_rate: 0.0010
# Epoch 2/40
# 4145/4145 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.4952 - loss: 1.4126
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 4145/4145 ━━━━━━━━━━━━━━━━━━━━ 394s 95ms/step - accuracy: 0.5166 - loss: 1.3513 - val_accuracy: 0.9025 - val_loss: 0.3371 - learning_rate: 0.0010
# Epoch 3/40
# 4145/4145 ━━━━━━━━━━━━━━━━━━━━ 394s 95ms/step - accuracy: 0.6007 - loss: 1.1195 - val_accuracy: 0.7822 - val_loss: 0.6860 - learning_rate: 0.0010
# Epoch 4/40
# 4145/4145 ━━━━━━━━━━━━━━━━━━━━ 394s 95ms/step - accuracy: 0.6788 - loss: 0.9113 - val_accuracy: 0.8897 - val_loss: 0.2869 - learning_rate: 0.0010
# Epoch 5/40
# 4145/4145 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7589 - loss: 0.6913
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 4145/4145 ━━━━━━━━━━━━━━━━━━━━ 395s 95ms/step - accuracy: 0.7844 - loss: 0.6210 - val_accuracy: 0.9531 - val_loss: 0.1256 - learning_rate: 0.0010
# Epoch 6/40
# 4145/4145 ━━━━━━━━━━━━━━━━━━━━ 395s 95ms/step - accuracy: 0.8625 - loss: 0.4040 - val_accuracy: 0.9330 - val_loss: 0.2110 - learning_rate: 0.0010
# Epoch 7/40
# 4145/4145 ━━━━━━━━━━━━━━━━━━━━ 395s 95ms/step - accuracy: 0.9086 - loss: 0.2660 - val_accuracy: 0.8769 - val_loss: 0.5064 - learning_rate: 0.0010
# Epoch 8/40
# 4145/4145 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9258 - loss: 0.2149

# %%
def convert_to_tflite(h5_path="../model/gesture_model.h5", tflite_path="../model/gesture_model.tflite"):
    import tensorflow as tf
    model = tf.keras.models.load_model(h5_path)
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]
    tflite_model = converter.convert()
    with open(tflite_path, "wb") as f:
        f.write(tflite_model)
    print("Saved TFLite model to", tflite_path)

convert_to_tflite()
# Out:
# 2025-10-15 13:09:19.488176: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2025-10-15 13:09:19.488218: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:178] verbose logging is disabled. Rerun with verbose logging (usually --v=1 or --vmodule=cuda_diagnostics=1) to get more diagnostic output from this module
# 2025-10-15 13:09:19.488227: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:183] retrieving CUDA diagnostic information for host: acer-predator-helio300
# 2025-10-15 13:09:19.488234: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:190] hostname: acer-predator-helio300
# 2025-10-15 13:09:19.488385: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:197] libcuda reported version is: 550.163.1
# 2025-10-15 13:09:19.488424: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:201] kernel reported version is: 550.163.1
# 2025-10-15 13:09:19.488429: I external/local_xla/xla/stream_executor/cuda/cuda_diagnostics.cc:291] kernel version seems to match DSO: 550.163.1
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: /tmp/tmphdkg93jy/assets
# INFO:tensorflow:Assets written to: /tmp/tmphdkg93jy/assets
# Saved artifact at '/tmp/tmphdkg93jy'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 64, 64, 1), dtype=tf.float32, name='input_layer_1')
# Output Type:
#   TensorSpec(shape=(None, 28), dtype=tf.float32, name=None)
# Captures:
#   123600933772496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123600933774608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123600933774800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123600933775376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123600933773456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123600933775568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123600933775952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123600933775760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123600933774224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123600933775184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123600933774992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123600933776528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123600933776144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123600933776720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123600933778448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123600933778640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123600933773840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123600933773648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123600933777104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123600933776912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123600933779408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   123600933778832: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved TFLite model to ../model/gesture_model.tflite
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1760513960.721903    6060 tf_tfl_flatbuffer_helpers.cc:365] Ignored output_format.
# W0000 00:00:1760513960.721935    6060 tf_tfl_flatbuffer_helpers.cc:368] Ignored drop_control_dependency.
# 2025-10-15 13:09:20.722699: I tensorflow/cc/saved_model/reader.cc:83] Reading SavedModel from: /tmp/tmphdkg93jy
# 2025-10-15 13:09:20.724343: I tensorflow/cc/saved_model/reader.cc:52] Reading meta graph with tags { serve }
# 2025-10-15 13:09:20.724357: I tensorflow/cc/saved_model/reader.cc:147] Reading SavedModel debug info (if present) from: /tmp/tmphdkg93jy
# I0000 00:00:1760513960.741299    6060 mlir_graph_optimization_pass.cc:425] MLIR V1 optimization pass is not enabled
# 2025-10-15 13:09:20.744504: I tensorflow/cc/saved_model/loader.cc:236] Restoring SavedModel bundle.
# 2025-10-15 13:09:20.861905: I tensorflow/cc/saved_model/loader.cc:220] Running initialization op on SavedModel bundle at path: /tmp/tmphdkg93jy
# 2025-10-15 13:09:20.891504: I tensorflow/cc/saved_model/loader.cc:471] SavedModel load for tags { serve }; Status: success: OK. Took 168808 microseconds.
# 2025-10-15 13:09:20.969930: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.

# %%
model_path="../model/gesture_model.h5"
class_names_path="class_names.json"

# %%
def run_webcam_inference(model_path, class_map_path):
    import tensorflow as tf
    import cv2
    import numpy as np
    import json


    model = tf.keras.models.load_model(model_path)
    with open(class_map_path, "r") as f:
        classes = json.load(f)


    cap = cv2.VideoCapture(1)
    if not cap.isOpened():
        print(" Error: Could not open webcam.")
        return

    print(" Webcam successfully opened!")

    while True:
        ret, frame = cap.read()
        if not ret or frame is None:
            print(" Failed to capture frame.")
            continue

    
        frame_gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        frame_resized = cv2.resize(frame_gray, (64, 64))
        img_in = frame_resized.astype("float32") / 255.0
        img_in = np.expand_dims(img_in, axis=(0, -1))  

        preds = model.predict(img_in, verbose=0)
        top_idx = np.argmax(preds[0])
        top_prob = preds[0][top_idx]
        label = classes[str(top_idx)] if isinstance(classes, dict) else classes[top_idx]

  
        text = f"{label}: {top_prob:.2f}"
        cv2.putText(frame, text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0, 255, 0), 2)
        cv2.imshow("Gesture Recognition", frame)

   
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

# %%
run_webcam_inference(model_path, class_names_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Webcam successfully opened!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 run_webcam_inference(model_path, class_names_path)
#
# Cell In[5], line 32, in run_webcam_inference(model_path, class_map_path)
#      29 img_in = frame_resized.astype("float32") / 255.0
#      30 img_in = np.expand_dims(img_in, axis=(0, -1))  # shape (1, 64, 64, 1)
# ---> 32 preds = model.predict(img_in, verbose=0)
#      33 top_idx = np.argmax(preds[0])
#      34 top_prob = preds[0][top_idx]
#
# File c:\Projects\sign-language-classification\.venv\lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Projects\sign-language-classification\.venv\lib\site-packages\keras\src\backend\tensorflow\trainer.py:563, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     561 outputs = None
#     562 with epoch_iterator.catch_stop_iteration():
# --> 563     for begin_step, end_step, iterator in epoch_iterator:
#     564         callbacks.on_predict_batch_begin(begin_step)
#     565         data = get_data(iterator)
#
# File c:\Projects\sign-language-classification\.venv\lib\site-packages\keras\src\backend\tensorflow\trainer.py:742, in TFEpochIterator.__next__(self)
#     741 def __next__(self):
# --> 742     return next(self._epoch_iterator)
#
# File c:\Projects\sign-language-classification\.venv\lib\site-packages\keras\src\trainers\epoch_iterator.py:125, in EpochIterator._enumerate_iterator(self)
#     119         yield (
#     120             step,
#     121             step + self.steps_per_execution - 1,
#     122             self._current_iterator,
#     123         )
#     124     if self._num_batches and self._steps_seen >= self._num_batches:
# --> 125         self._current_iterator = iter(self._get_iterator())
#     126         self._steps_seen = 0
#     127 else:
#
# File c:\Projects\sign-language-classification\.venv\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:501, in DatasetV2.__iter__(self)
#     499 if context.executing_eagerly() or ops.inside_function():
#     500   with ops.colocate_with(self._variant_tensor):
# --> 501     return iterator_ops.OwnedIterator(self)
#     502 else:
#     503   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     504                      "iteration in eager mode or within tf.function.")
#
# File c:\Projects\sign-language-classification\.venv\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:709, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     705   if (components is not None or element_spec is not None):
#     706     raise ValueError(
#     707         "When `dataset` is provided, `element_spec` and `components` must "
#     708         "not be specified.")
# --> 709   self._create_iterator(dataset)
#     711 self._get_next_call_count = 0
#
# File c:\Projects\sign-language-classification\.venv\lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:748, in OwnedIterator._create_iterator(self, dataset)
#     745   assert len(fulltype.args[0].args[0].args) == len(
#     746       self._flat_output_types)
#     747   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 748 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File c:\Projects\sign-language-classification\.venv\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3478, in make_iterator(dataset, iterator, name)
#    3476 if tld.is_eager:
#    3477   try:
# -> 3478     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3479       _ctx, "MakeIterator", name, dataset, iterator)
#    3480     return _result
#    3481   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
